# %% [markdown]
# # Colores - Matplotlib

# %%
import matplotlib.colors as mcolors
sorted_color_names = sorted(mcolors.CSS4_COLORS, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
def crear_tabla_completa_colores(filas=37, mostrar_directamente=True):
    """
    Crea una tabla completa con todos los colores organizados en el número de filas especificado
    
    Parámetros:
    -----------
    filas : int
        Número de filas para organizar la tabla (default: 37)
    mostrar_directamente : bool
        Si True, muestra el resultado renderizado. Si False, devuelve el string Markdown
    """
    global sorted_color_names
    
    if not sorted_color_names:
        print("⚠️  Primero ejecuta la celda que crea sorted_color_names")
        return "⚠️ Lista de colores no disponible"
    
    import matplotlib.colors as mcolors
    import math
    
    total_colores = len(sorted_color_names)
    columnas = math.ceil(total_colores / filas)
    
    print(f"📊 Organizando {total_colores} colores en {filas} filas y {columnas} columnas")
    
    # Crear encabezados de la tabla (sin columna de fila)
    headers = [f"Color {i+1}" for i in range(columnas)]
    
    # Crear la tabla Markdown con estilo mejorado (compacto)
    markdown_output = f"## Tabla Completa de Colores ({filas} filas × {columnas} columnas)\n\n"
    
    # CSS compacto con texto más grande
    markdown_output += """<style>
.color-table {width: 100%; border-collapse: collapse; font-family: Arial, sans-serif;}
.color-table th, .color-table td {text-align: center; vertical-align: middle; padding: 12px 8px; border: 1px solid #ddd; min-width: 90px;}
.color-table th {background-color: #f5f5f5; font-weight: bold; font-size: 16px;}
.color-table td {font-size: 14px;}
.color-block {display: inline-block; width: 28px; height: 28px; border-radius: 4px; margin-bottom: 6px; border: 2px solid #333;}
.color-name {font-weight: bold; font-size: 14px; display: block; margin-top: 4px;}
.color-hex {font-size: 12px; font-family: monospace; margin-top: 3px;}
</style>
<table class="color-table"><thead><tr>""" + "".join([f"<th>{header}</th>" for header in headers]) + """</tr></thead><tbody>"""
    
    # Llenar la tabla (sin columna de fila)
    for fila in range(filas):
        markdown_output += "<tr>"
        
        for col in range(columnas):
            indice = fila + (col * filas)
            
            if indice < total_colores:
                color_name = sorted_color_names[indice]
                
                # Obtener código hex
                if color_name in mcolors.CSS4_COLORS:
                    hex_color = mcolors.CSS4_COLORS[color_name]
                else:
                    hex_color = '#808080'  # Gris por defecto
                
                # Crear celda sin emojis
                celda_contenido = f"""<div style="text-align: center;">
                <div class="color-block" style="background-color: {hex_color}; display: inline-block;"></div>
                <div class="color-name" style="color: {hex_color}; font-size: 15px;"><strong>{color_name}</strong></div>
                <div class="color-hex" style="color: #666; font-size: 13px;">{hex_color}</div>
                </div>"""
            else:
                celda_contenido = "<div style='text-align: center; color: #ccc;'>-</div>"
            
            markdown_output += f"<td>{celda_contenido}</td>"
        
        markdown_output += "</tr>"
    
    markdown_output += "</tbody></table>"
    
    if mostrar_directamente:
        from IPython.display import Markdown, display
        display(Markdown(markdown_output))
    else:
        return markdown_output

# %%
crear_tabla_completa_colores(filas=25)
# Out:
# 📊 Organizando 148 colores en 25 filas y 6 columnas
# ## Tabla Completa de Colores (25 filas × 6 columnas)
#
# <style>
# .color-table {width: 100%; border-collapse: collapse; font-family: Arial, sans-serif;}
# .color-table th, .color-table td {text-align: center; vertical-align: middle; padding: 12px 8px; border: 1px solid #ddd; min-width: 90px;}
# .color-table th {background-color: #f5f5f5; font-weight: bold; font-size: 16px;}
# .color-table td {font-size: 14px;}
# .color-block {display: inline-block; width: 28px; height: 28px; border-radius: 4px; margin-bottom: 6px; border: 2px solid #333;}
# .color-name {font-weight: bold; font-size: 14px; display: block; margin-top: 4px;}
# .color-hex {font-size: 12px; font-family: monospace; margin-top: 3px;}
# </style>
# <table class="color-table"><thead><tr><th>Color 1</th><th>Color 2</th><th>Color 3</th><th>Color 4</th><th>Color 5</th><th>Color 6</th></tr></thead><tbody><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #000000; display: inline-block;"></div>
#                 <div class="color-name" style="color: #000000; font-size: 15px;"><strong>black</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#000000</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #E9967A; display: inline-block;"></div>
#                 <div class="color-name" style="color: #E9967A; font-size: 15px;"><strong>darksalmon</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#E9967A</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #B8860B; display: inline-block;"></div>
#                 <div class="color-name" style="color: #B8860B; font-size: 15px;"><strong>darkgoldenrod</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#B8860B</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #32CD32; display: inline-block;"></div>
#                 <div class="color-name" style="color: #32CD32; font-size: 15px;"><strong>limegreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#32CD32</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #B0E0E6; display: inline-block;"></div>
#                 <div class="color-name" style="color: #B0E0E6; font-size: 15px;"><strong>powderblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#B0E0E6</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #9370DB; display: inline-block;"></div>
#                 <div class="color-name" style="color: #9370DB; font-size: 15px;"><strong>mediumpurple</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#9370DB</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #696969; display: inline-block;"></div>
#                 <div class="color-name" style="color: #696969; font-size: 15px;"><strong>dimgray</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#696969</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FF7F50; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FF7F50; font-size: 15px;"><strong>coral</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FF7F50</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #DAA520; display: inline-block;"></div>
#                 <div class="color-name" style="color: #DAA520; font-size: 15px;"><strong>goldenrod</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#DAA520</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #006400; display: inline-block;"></div>
#                 <div class="color-name" style="color: #006400; font-size: 15px;"><strong>darkgreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#006400</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #ADD8E6; display: inline-block;"></div>
#                 <div class="color-name" style="color: #ADD8E6; font-size: 15px;"><strong>lightblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#ADD8E6</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #663399; display: inline-block;"></div>
#                 <div class="color-name" style="color: #663399; font-size: 15px;"><strong>rebeccapurple</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#663399</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #696969; display: inline-block;"></div>
#                 <div class="color-name" style="color: #696969; font-size: 15px;"><strong>dimgrey</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#696969</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FF4500; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FF4500; font-size: 15px;"><strong>orangered</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FF4500</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFF8DC; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFF8DC; font-size: 15px;"><strong>cornsilk</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFF8DC</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #008000; display: inline-block;"></div>
#                 <div class="color-name" style="color: #008000; font-size: 15px;"><strong>green</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#008000</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #00BFFF; display: inline-block;"></div>
#                 <div class="color-name" style="color: #00BFFF; font-size: 15px;"><strong>deepskyblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#00BFFF</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #8A2BE2; display: inline-block;"></div>
#                 <div class="color-name" style="color: #8A2BE2; font-size: 15px;"><strong>blueviolet</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#8A2BE2</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #808080; display: inline-block;"></div>
#                 <div class="color-name" style="color: #808080; font-size: 15px;"><strong>gray</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#808080</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFA07A; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFA07A; font-size: 15px;"><strong>lightsalmon</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFA07A</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFD700; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFD700; font-size: 15px;"><strong>gold</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFD700</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #00FF00; display: inline-block;"></div>
#                 <div class="color-name" style="color: #00FF00; font-size: 15px;"><strong>lime</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#00FF00</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #87CEEB; display: inline-block;"></div>
#                 <div class="color-name" style="color: #87CEEB; font-size: 15px;"><strong>skyblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#87CEEB</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #4B0082; display: inline-block;"></div>
#                 <div class="color-name" style="color: #4B0082; font-size: 15px;"><strong>indigo</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#4B0082</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #808080; display: inline-block;"></div>
#                 <div class="color-name" style="color: #808080; font-size: 15px;"><strong>grey</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#808080</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #A0522D; display: inline-block;"></div>
#                 <div class="color-name" style="color: #A0522D; font-size: 15px;"><strong>sienna</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#A0522D</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFFACD; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFFACD; font-size: 15px;"><strong>lemonchiffon</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFFACD</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #2E8B57; display: inline-block;"></div>
#                 <div class="color-name" style="color: #2E8B57; font-size: 15px;"><strong>seagreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#2E8B57</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #87CEFA; display: inline-block;"></div>
#                 <div class="color-name" style="color: #87CEFA; font-size: 15px;"><strong>lightskyblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#87CEFA</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #9932CC; display: inline-block;"></div>
#                 <div class="color-name" style="color: #9932CC; font-size: 15px;"><strong>darkorchid</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#9932CC</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #A9A9A9; display: inline-block;"></div>
#                 <div class="color-name" style="color: #A9A9A9; font-size: 15px;"><strong>darkgray</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#A9A9A9</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFF5EE; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFF5EE; font-size: 15px;"><strong>seashell</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFF5EE</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #F0E68C; display: inline-block;"></div>
#                 <div class="color-name" style="color: #F0E68C; font-size: 15px;"><strong>khaki</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#F0E68C</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #3CB371; display: inline-block;"></div>
#                 <div class="color-name" style="color: #3CB371; font-size: 15px;"><strong>mediumseagreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#3CB371</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #4682B4; display: inline-block;"></div>
#                 <div class="color-name" style="color: #4682B4; font-size: 15px;"><strong>steelblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#4682B4</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #9400D3; display: inline-block;"></div>
#                 <div class="color-name" style="color: #9400D3; font-size: 15px;"><strong>darkviolet</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#9400D3</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #A9A9A9; display: inline-block;"></div>
#                 <div class="color-name" style="color: #A9A9A9; font-size: 15px;"><strong>darkgrey</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#A9A9A9</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #D2691E; display: inline-block;"></div>
#                 <div class="color-name" style="color: #D2691E; font-size: 15px;"><strong>chocolate</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#D2691E</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #EEE8AA; display: inline-block;"></div>
#                 <div class="color-name" style="color: #EEE8AA; font-size: 15px;"><strong>palegoldenrod</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#EEE8AA</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #00FF7F; display: inline-block;"></div>
#                 <div class="color-name" style="color: #00FF7F; font-size: 15px;"><strong>springgreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#00FF7F</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #F0F8FF; display: inline-block;"></div>
#                 <div class="color-name" style="color: #F0F8FF; font-size: 15px;"><strong>aliceblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#F0F8FF</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #BA55D3; display: inline-block;"></div>
#                 <div class="color-name" style="color: #BA55D3; font-size: 15px;"><strong>mediumorchid</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#BA55D3</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #C0C0C0; display: inline-block;"></div>
#                 <div class="color-name" style="color: #C0C0C0; font-size: 15px;"><strong>silver</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#C0C0C0</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #8B4513; display: inline-block;"></div>
#                 <div class="color-name" style="color: #8B4513; font-size: 15px;"><strong>saddlebrown</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#8B4513</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #BDB76B; display: inline-block;"></div>
#                 <div class="color-name" style="color: #BDB76B; font-size: 15px;"><strong>darkkhaki</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#BDB76B</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #F5FFFA; display: inline-block;"></div>
#                 <div class="color-name" style="color: #F5FFFA; font-size: 15px;"><strong>mintcream</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#F5FFFA</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #1E90FF; display: inline-block;"></div>
#                 <div class="color-name" style="color: #1E90FF; font-size: 15px;"><strong>dodgerblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#1E90FF</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #D8BFD8; display: inline-block;"></div>
#                 <div class="color-name" style="color: #D8BFD8; font-size: 15px;"><strong>thistle</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#D8BFD8</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #D3D3D3; display: inline-block;"></div>
#                 <div class="color-name" style="color: #D3D3D3; font-size: 15px;"><strong>lightgray</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#D3D3D3</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #F4A460; display: inline-block;"></div>
#                 <div class="color-name" style="color: #F4A460; font-size: 15px;"><strong>sandybrown</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#F4A460</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFFFF0; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFFFF0; font-size: 15px;"><strong>ivory</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFFFF0</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #00FA9A; display: inline-block;"></div>
#                 <div class="color-name" style="color: #00FA9A; font-size: 15px;"><strong>mediumspringgreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#00FA9A</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #778899; display: inline-block;"></div>
#                 <div class="color-name" style="color: #778899; font-size: 15px;"><strong>lightslategray</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#778899</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #DDA0DD; display: inline-block;"></div>
#                 <div class="color-name" style="color: #DDA0DD; font-size: 15px;"><strong>plum</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#DDA0DD</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #D3D3D3; display: inline-block;"></div>
#                 <div class="color-name" style="color: #D3D3D3; font-size: 15px;"><strong>lightgrey</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#D3D3D3</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFDAB9; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFDAB9; font-size: 15px;"><strong>peachpuff</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFDAB9</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #F5F5DC; display: inline-block;"></div>
#                 <div class="color-name" style="color: #F5F5DC; font-size: 15px;"><strong>beige</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#F5F5DC</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #66CDAA; display: inline-block;"></div>
#                 <div class="color-name" style="color: #66CDAA; font-size: 15px;"><strong>mediumaquamarine</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#66CDAA</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #778899; display: inline-block;"></div>
#                 <div class="color-name" style="color: #778899; font-size: 15px;"><strong>lightslategrey</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#778899</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #EE82EE; display: inline-block;"></div>
#                 <div class="color-name" style="color: #EE82EE; font-size: 15px;"><strong>violet</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#EE82EE</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #DCDCDC; display: inline-block;"></div>
#                 <div class="color-name" style="color: #DCDCDC; font-size: 15px;"><strong>gainsboro</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#DCDCDC</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #CD853F; display: inline-block;"></div>
#                 <div class="color-name" style="color: #CD853F; font-size: 15px;"><strong>peru</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#CD853F</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFFFE0; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFFFE0; font-size: 15px;"><strong>lightyellow</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFFFE0</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #7FFFD4; display: inline-block;"></div>
#                 <div class="color-name" style="color: #7FFFD4; font-size: 15px;"><strong>aquamarine</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#7FFFD4</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #708090; display: inline-block;"></div>
#                 <div class="color-name" style="color: #708090; font-size: 15px;"><strong>slategray</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#708090</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #800080; display: inline-block;"></div>
#                 <div class="color-name" style="color: #800080; font-size: 15px;"><strong>purple</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#800080</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #F5F5F5; display: inline-block;"></div>
#                 <div class="color-name" style="color: #F5F5F5; font-size: 15px;"><strong>whitesmoke</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#F5F5F5</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FAF0E6; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FAF0E6; font-size: 15px;"><strong>linen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FAF0E6</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FAFAD2; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FAFAD2; font-size: 15px;"><strong>lightgoldenrodyellow</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FAFAD2</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #40E0D0; display: inline-block;"></div>
#                 <div class="color-name" style="color: #40E0D0; font-size: 15px;"><strong>turquoise</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#40E0D0</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #708090; display: inline-block;"></div>
#                 <div class="color-name" style="color: #708090; font-size: 15px;"><strong>slategrey</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#708090</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #8B008B; display: inline-block;"></div>
#                 <div class="color-name" style="color: #8B008B; font-size: 15px;"><strong>darkmagenta</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#8B008B</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFFFFF; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFFFFF; font-size: 15px;"><strong>white</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFFFFF</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFE4C4; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFE4C4; font-size: 15px;"><strong>bisque</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFE4C4</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #808000; display: inline-block;"></div>
#                 <div class="color-name" style="color: #808000; font-size: 15px;"><strong>olive</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#808000</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #20B2AA; display: inline-block;"></div>
#                 <div class="color-name" style="color: #20B2AA; font-size: 15px;"><strong>lightseagreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#20B2AA</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #B0C4DE; display: inline-block;"></div>
#                 <div class="color-name" style="color: #B0C4DE; font-size: 15px;"><strong>lightsteelblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#B0C4DE</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FF00FF; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FF00FF; font-size: 15px;"><strong>fuchsia</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FF00FF</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFFAFA; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFFAFA; font-size: 15px;"><strong>snow</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFFAFA</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FF8C00; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FF8C00; font-size: 15px;"><strong>darkorange</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FF8C00</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFFF00; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFFF00; font-size: 15px;"><strong>yellow</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFFF00</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #48D1CC; display: inline-block;"></div>
#                 <div class="color-name" style="color: #48D1CC; font-size: 15px;"><strong>mediumturquoise</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#48D1CC</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #6495ED; display: inline-block;"></div>
#                 <div class="color-name" style="color: #6495ED; font-size: 15px;"><strong>cornflowerblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#6495ED</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FF00FF; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FF00FF; font-size: 15px;"><strong>magenta</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FF00FF</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #BC8F8F; display: inline-block;"></div>
#                 <div class="color-name" style="color: #BC8F8F; font-size: 15px;"><strong>rosybrown</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#BC8F8F</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #DEB887; display: inline-block;"></div>
#                 <div class="color-name" style="color: #DEB887; font-size: 15px;"><strong>burlywood</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#DEB887</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #6B8E23; display: inline-block;"></div>
#                 <div class="color-name" style="color: #6B8E23; font-size: 15px;"><strong>olivedrab</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#6B8E23</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #F0FFFF; display: inline-block;"></div>
#                 <div class="color-name" style="color: #F0FFFF; font-size: 15px;"><strong>azure</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#F0FFFF</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #4169E1; display: inline-block;"></div>
#                 <div class="color-name" style="color: #4169E1; font-size: 15px;"><strong>royalblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#4169E1</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #DA70D6; display: inline-block;"></div>
#                 <div class="color-name" style="color: #DA70D6; font-size: 15px;"><strong>orchid</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#DA70D6</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #F08080; display: inline-block;"></div>
#                 <div class="color-name" style="color: #F08080; font-size: 15px;"><strong>lightcoral</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#F08080</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FAEBD7; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FAEBD7; font-size: 15px;"><strong>antiquewhite</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FAEBD7</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #9ACD32; display: inline-block;"></div>
#                 <div class="color-name" style="color: #9ACD32; font-size: 15px;"><strong>yellowgreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#9ACD32</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #E0FFFF; display: inline-block;"></div>
#                 <div class="color-name" style="color: #E0FFFF; font-size: 15px;"><strong>lightcyan</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#E0FFFF</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #F8F8FF; display: inline-block;"></div>
#                 <div class="color-name" style="color: #F8F8FF; font-size: 15px;"><strong>ghostwhite</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#F8F8FF</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #C71585; display: inline-block;"></div>
#                 <div class="color-name" style="color: #C71585; font-size: 15px;"><strong>mediumvioletred</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#C71585</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #CD5C5C; display: inline-block;"></div>
#                 <div class="color-name" style="color: #CD5C5C; font-size: 15px;"><strong>indianred</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#CD5C5C</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #D2B48C; display: inline-block;"></div>
#                 <div class="color-name" style="color: #D2B48C; font-size: 15px;"><strong>tan</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#D2B48C</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #556B2F; display: inline-block;"></div>
#                 <div class="color-name" style="color: #556B2F; font-size: 15px;"><strong>darkolivegreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#556B2F</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #AFEEEE; display: inline-block;"></div>
#                 <div class="color-name" style="color: #AFEEEE; font-size: 15px;"><strong>paleturquoise</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#AFEEEE</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #E6E6FA; display: inline-block;"></div>
#                 <div class="color-name" style="color: #E6E6FA; font-size: 15px;"><strong>lavender</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#E6E6FA</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FF1493; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FF1493; font-size: 15px;"><strong>deeppink</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FF1493</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #A52A2A; display: inline-block;"></div>
#                 <div class="color-name" style="color: #A52A2A; font-size: 15px;"><strong>brown</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#A52A2A</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFDEAD; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFDEAD; font-size: 15px;"><strong>navajowhite</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFDEAD</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #ADFF2F; display: inline-block;"></div>
#                 <div class="color-name" style="color: #ADFF2F; font-size: 15px;"><strong>greenyellow</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#ADFF2F</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #2F4F4F; display: inline-block;"></div>
#                 <div class="color-name" style="color: #2F4F4F; font-size: 15px;"><strong>darkslategray</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#2F4F4F</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #191970; display: inline-block;"></div>
#                 <div class="color-name" style="color: #191970; font-size: 15px;"><strong>midnightblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#191970</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FF69B4; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FF69B4; font-size: 15px;"><strong>hotpink</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FF69B4</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #B22222; display: inline-block;"></div>
#                 <div class="color-name" style="color: #B22222; font-size: 15px;"><strong>firebrick</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#B22222</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFEBCD; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFEBCD; font-size: 15px;"><strong>blanchedalmond</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFEBCD</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #7FFF00; display: inline-block;"></div>
#                 <div class="color-name" style="color: #7FFF00; font-size: 15px;"><strong>chartreuse</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#7FFF00</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #2F4F4F; display: inline-block;"></div>
#                 <div class="color-name" style="color: #2F4F4F; font-size: 15px;"><strong>darkslategrey</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#2F4F4F</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #000080; display: inline-block;"></div>
#                 <div class="color-name" style="color: #000080; font-size: 15px;"><strong>navy</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#000080</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFF0F5; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFF0F5; font-size: 15px;"><strong>lavenderblush</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFF0F5</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #800000; display: inline-block;"></div>
#                 <div class="color-name" style="color: #800000; font-size: 15px;"><strong>maroon</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#800000</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFEFD5; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFEFD5; font-size: 15px;"><strong>papayawhip</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFEFD5</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #7CFC00; display: inline-block;"></div>
#                 <div class="color-name" style="color: #7CFC00; font-size: 15px;"><strong>lawngreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#7CFC00</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #008080; display: inline-block;"></div>
#                 <div class="color-name" style="color: #008080; font-size: 15px;"><strong>teal</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#008080</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #00008B; display: inline-block;"></div>
#                 <div class="color-name" style="color: #00008B; font-size: 15px;"><strong>darkblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#00008B</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #DB7093; display: inline-block;"></div>
#                 <div class="color-name" style="color: #DB7093; font-size: 15px;"><strong>palevioletred</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#DB7093</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #8B0000; display: inline-block;"></div>
#                 <div class="color-name" style="color: #8B0000; font-size: 15px;"><strong>darkred</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#8B0000</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFE4B5; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFE4B5; font-size: 15px;"><strong>moccasin</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFE4B5</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #F0FFF0; display: inline-block;"></div>
#                 <div class="color-name" style="color: #F0FFF0; font-size: 15px;"><strong>honeydew</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#F0FFF0</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #008B8B; display: inline-block;"></div>
#                 <div class="color-name" style="color: #008B8B; font-size: 15px;"><strong>darkcyan</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#008B8B</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #0000CD; display: inline-block;"></div>
#                 <div class="color-name" style="color: #0000CD; font-size: 15px;"><strong>mediumblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#0000CD</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #DC143C; display: inline-block;"></div>
#                 <div class="color-name" style="color: #DC143C; font-size: 15px;"><strong>crimson</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#DC143C</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FF0000; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FF0000; font-size: 15px;"><strong>red</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FF0000</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFA500; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFA500; font-size: 15px;"><strong>orange</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFA500</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #8FBC8F; display: inline-block;"></div>
#                 <div class="color-name" style="color: #8FBC8F; font-size: 15px;"><strong>darkseagreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#8FBC8F</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #00FFFF; display: inline-block;"></div>
#                 <div class="color-name" style="color: #00FFFF; font-size: 15px;"><strong>aqua</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#00FFFF</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #0000FF; display: inline-block;"></div>
#                 <div class="color-name" style="color: #0000FF; font-size: 15px;"><strong>blue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#0000FF</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFC0CB; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFC0CB; font-size: 15px;"><strong>pink</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFC0CB</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFE4E1; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFE4E1; font-size: 15px;"><strong>mistyrose</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFE4E1</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #F5DEB3; display: inline-block;"></div>
#                 <div class="color-name" style="color: #F5DEB3; font-size: 15px;"><strong>wheat</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#F5DEB3</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #98FB98; display: inline-block;"></div>
#                 <div class="color-name" style="color: #98FB98; font-size: 15px;"><strong>palegreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#98FB98</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #00FFFF; display: inline-block;"></div>
#                 <div class="color-name" style="color: #00FFFF; font-size: 15px;"><strong>cyan</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#00FFFF</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #6A5ACD; display: inline-block;"></div>
#                 <div class="color-name" style="color: #6A5ACD; font-size: 15px;"><strong>slateblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#6A5ACD</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFB6C1; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFB6C1; font-size: 15px;"><strong>lightpink</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFB6C1</div>
#                 </div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FA8072; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FA8072; font-size: 15px;"><strong>salmon</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FA8072</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FDF5E6; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FDF5E6; font-size: 15px;"><strong>oldlace</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FDF5E6</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #90EE90; display: inline-block;"></div>
#                 <div class="color-name" style="color: #90EE90; font-size: 15px;"><strong>lightgreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#90EE90</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #00CED1; display: inline-block;"></div>
#                 <div class="color-name" style="color: #00CED1; font-size: 15px;"><strong>darkturquoise</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#00CED1</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #483D8B; display: inline-block;"></div>
#                 <div class="color-name" style="color: #483D8B; font-size: 15px;"><strong>darkslateblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#483D8B</div>
#                 </div></td><td><div style='text-align: center; color: #ccc;'>-</div></td></tr><tr><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FF6347; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FF6347; font-size: 15px;"><strong>tomato</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FF6347</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #FFFAF0; display: inline-block;"></div>
#                 <div class="color-name" style="color: #FFFAF0; font-size: 15px;"><strong>floralwhite</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#FFFAF0</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #228B22; display: inline-block;"></div>
#                 <div class="color-name" style="color: #228B22; font-size: 15px;"><strong>forestgreen</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#228B22</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #5F9EA0; display: inline-block;"></div>
#                 <div class="color-name" style="color: #5F9EA0; font-size: 15px;"><strong>cadetblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#5F9EA0</div>
#                 </div></td><td><div style="text-align: center;">
#                 <div class="color-block" style="background-color: #7B68EE; display: inline-block;"></div>
#                 <div class="color-name" style="color: #7B68EE; font-size: 15px;"><strong>mediumslateblue</strong></div>
#                 <div class="color-hex" style="color: #666; font-size: 13px;">#7B68EE</div>
#                 </div></td><td><div style='text-align: center; color: #ccc;'>-</div></td></tr></tbody></table>

# %%
import math

import matplotlib.pyplot as plt

import matplotlib.colors as mcolors
from matplotlib.patches import Rectangle


def plot_colortable(colors, *, ncols=5, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * ncols + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * ncols)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig
plot_colortable(mcolors.CSS4_COLORS)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import random

def graficar_barras_por_lotes(lote=30):
    """
    Crea gráficos de barras usando la lista ordenada de colores HSV
    """
    global sorted_color_names
    
    if not sorted_color_names:
        print("⚠️  Primero ejecuta la celda que crea sorted_color_names")
        return
    
    nombres = sorted_color_names  # Usar la lista ordenada por HSV
    total = len(nombres)
    lotes = [nombres[i:i + lote] for i in range(0, total, lote)]

    for i, grupo in enumerate(lotes, 1):
        valores = [random.randint(1, 10) for _ in grupo]
        # Obtener colores usando la misma lógica que crear_tabla_completa_colores
        colores_lote = [mcolors.CSS4_COLORS[nombre] for nombre in grupo]

        fig, ax = plt.subplots(figsize=(max(12, len(grupo) * 0.6), 6))
        barras = ax.bar(grupo, valores, color=colores_lote, edgecolor='#e0e0e0')

        for bar, name in zip(barras, grupo):
            height = bar.get_height()
            ax.text(bar.get_x() + bar.get_width() / 2, height + 0.3,
                    name, ha='center', va='bottom', rotation=90, fontsize=10)

        ax.set_title(f'Colores del {((i - 1) * lote) + 1} al {min(i * lote, total)} (Ordenados por HSV)',
                     fontsize=14, weight='bold')
        ax.set_xticks([])
        ax.set_ylim(0, 20)
        ax.set_facecolor('#f9f9f9')
        fig.patch.set_facecolor('#f9f9f9')
        plt.tight_layout()
        plt.show()

# Ejecutar con los colores ordenados por HSV
graficar_barras_por_lotes(lote=30)
